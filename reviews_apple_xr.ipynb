# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url = "https://www.mouthshut.com/mobile-phones/Apple-iPhone-XR-reviews-925945566"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='col-10 review']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 100

# %%
print(all_section[6])
# Out:
# NOT CONVINCED WITH SPECS.
# Apr 03, 2019 05:54 PM2944 Views
# I used this device only 5 days because I borrowed it with my friend to check how it is actually working and I observed some very bad parts of this smartphone, I am gonna sharing those with you.CHARGING:- I phone always have same issues regarding with charging, they give you fast charging sup...Read More
# Reply As Brand
# Like
# (2)
# Comments (2)

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,100),columns=['review','posted_time','experience'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #review
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #posted_time
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #experience
    except IndexError:
        df.iloc[idx,2]=np.nan

# %%
df
# Out:
#                                        review  \
# 0                            Not worth to buy
# 1                            The money sekers
# 2                  Best phone but not for all
# 3            IPHONE XR THE BEST ONE CAN HAVE.
# 4                                   Fab phone
# 5                                   Iphone xr
# 6                   NOT CONVINCED WITH SPECS.
# 7                       Love it for having it
# 8         One of the best i phone till now...
# 9   Probably the best iPhone created by Apple
# 10                                   IPhone x
# 11                               Apple iPhone
# 12                    Not good for more money
# 13                               SMART PHONES
# 14                     One of the best iphone
# 15                         I phone feature...
# 16                             Very Expensive
# 17                             Amazing design
# 18                    Love it bro i need this
# 19                                         Ok
# 20                           Not worth to buy
# 21                           The money sekers
# 22                 Best phone but not for all
# 23           IPHONE XR THE BEST ONE CAN HAVE.
# 24                                  Fab phone
# 25                                  Iphone xr
# 26                  NOT CONVINCED WITH SPECS.
# 27                      Love it for having it
# 28        One of the best i phone till now...
# 29  Probably the best iPhone created by Apple
# ..                                        ...
# 70                                   IPhone x
# 71                               Apple iPhone
# 72                    Not good for more money
# 73                               SMART PHONES
# 74                     One of the best iphone
# 75                         I phone feature...
# 76                             Very Expensive
# 77                             Amazing design
# 78                    Love it bro i need this
# 79                                         Ok
# 80                           Not worth to buy
# 81                           The money sekers
# 82                 Best phone but not for all
# 83           IPHONE XR THE BEST ONE CAN HAVE.
# 84                                  Fab phone
# 85                                  Iphone xr
# 86                  NOT CONVINCED WITH SPECS.
# 87                      Love it for having it
# 88        One of the best i phone till now...
# 89  Probably the best iPhone created by Apple
# 90                                   IPhone x
# 91                               Apple iPhone
# 92                    Not good for more money
# 93                               SMART PHONES
# 94                     One of the best iphone
# 95                         I phone feature...
# 96                             Very Expensive
# 97                             Amazing design
# 98                    Love it bro i need this
# 99                                         Ok
#
#                                           posted_time  \
# 0                   12 days agoRead (via Android App)
# 1                           Jun 17, 2019 06:54 PMRead
# 2   Jun 01, 2019 08:12 PM1239 Views (via Android App)
# 3                                       1 day agoRead
# 4                3 days ago73 Views (via Android App)
# 5        Jun 14, 2019 01:26 PM919 Views (via iOS App)
# 6                     Apr 03, 2019 05:54 PM2944 Views
# 7       Feb 15, 2019 11:52 PM2775 Views (via iOS App)
# 8   Nov 20, 2018 03:54 AM3187 Views (via Android App)
# 9   Nov 11, 2018 01:58 PM2869 Views (via Android App)
# 10             1 hr 51 mins agoRead (via Android App)
# 11             25 days ago446 Views (via Android App)
# 12                  27 days agoRead (via Android App)
# 13   Jun 30, 2019 01:59 PM493 Views (via Android App)
# 14       Jun 26, 2019 03:12 PM543 Views (via iOS App)
# 15   Jun 24, 2019 09:40 PM537 Views (via Android App)
# 16   Jun 24, 2019 04:39 PM576 Views (via Android App)
# 17   Jun 22, 2019 11:41 AM544 Views (via Android App)
# 18   Jun 19, 2019 01:59 AM672 Views (via Android App)
# 19                     Jun 15, 2019 03:22 PM656 Views
# 20                  12 days agoRead (via Android App)
# 21                          Jun 17, 2019 06:54 PMRead
# 22  Jun 01, 2019 08:12 PM1240 Views (via Android App)
# 23                                 2 days ago64 Views
# 24                   2 days agoRead (via Android App)
# 25       Jun 14, 2019 01:26 PM920 Views (via iOS App)
# 26                    Apr 03, 2019 05:54 PM2945 Views
# 27      Feb 15, 2019 11:52 PM2776 Views (via iOS App)
# 28  Nov 20, 2018 03:54 AM3188 Views (via Android App)
# 29  Nov 11, 2018 01:58 PM2870 Views (via Android App)
# ..                                                ...
# 70                1 day ago40 Views (via Android App)
# 71             25 days ago448 Views (via Android App)
# 72             28 days ago442 Views (via Android App)
# 73   Jun 30, 2019 01:59 PM495 Views (via Android App)
# 74       Jun 26, 2019 03:12 PM545 Views (via iOS App)
# 75   Jun 24, 2019 09:40 PM539 Views (via Android App)
# 76   Jun 24, 2019 04:39 PM578 Views (via Android App)
# 77        Jun 22, 2019 11:41 AMRead (via Android App)
# 78   Jun 19, 2019 01:59 AM674 Views (via Android App)
# 79                     Jun 15, 2019 03:22 PM658 Views
# 80                  12 days agoRead (via Android App)
# 81                          Jun 17, 2019 06:54 PMRead
# 82        Jun 01, 2019 08:12 PMRead (via Android App)
# 83                                      1 day agoRead
# 84                   2 days agoRead (via Android App)
# 85            Jun 14, 2019 01:26 PMRead (via iOS App)
# 86                          Apr 03, 2019 05:54 PMRead
# 87            Feb 15, 2019 11:52 PMRead (via iOS App)
# 88  Nov 20, 2018 03:54 AM3190 Views (via Android App)
# 89  Nov 11, 2018 01:58 PM2872 Views (via Android App)
# 90                1 day ago41 Views (via Android App)
# 91             25 days ago449 Views (via Android App)
# 92             28 days ago443 Views (via Android App)
# 93   Jun 30, 2019 01:59 PM496 Views (via Android App)
# 94       Jun 26, 2019 03:12 PM546 Views (via iOS App)
# 95   Jun 24, 2019 09:40 PM540 Views (via Android App)
# 96   Jun 24, 2019 04:39 PM579 Views (via Android App)
# 97   Jun 22, 2019 11:41 AM547 Views (via Android App)
# 98   Jun 19, 2019 01:59 AM675 Views (via Android App)
# 99                     Jun 15, 2019 03:22 PM659 Views
#
#                                            experience
# 0   I think this phone is just meant for showoff a...
# 1   The worst phone a person could ever have in hi...
# 2   Guys .,My friend have I phone xr ,And I have r...
# 3   I HAVE NEVER BEEN AN IPHONE USER UNTIL LAST TI...
# 4   I just upgraded from an iphone8 to the iphone ...
# 5   Yesterday my brother brought I phone xr for hi...
# 6   I used this device only 5 days because I borro...
# 7   Bought it 5 days before . I love this phone wi...
# 8   This I phone promises a premium design, look, ...
# 9   This iPhone is probably the best iPhone that A...
# 10  My both sister have iPhone and whenever I see ...
# 11  Best product.Apple iPhoneI like product.I thin...
# 12  It is not good for money because we get more m...
# 13  Apple we also know the apple a huge mobile , w...
# 14  Everyone knows that its very costly but to be ...
# 15  I phones is giid phones but costly so Better t...
# 16  It has been a month since I started using my i...
# 17  Whole feathure are amazing.Eas4th to use. Desi...
# 18  Woooh I never seen this iphone xr I have iphon...
# 19  Very nice phone. I love this. I am going to bu...
# 20  I think this phone is just meant for showoff a...
# 21  The worst phone a person could ever have in hi...
# 22  Guys .,My friend have I phone xr ,And I have r...
# 23  I HAVE NEVER BEEN AN IPHONE USER UNTIL LAST TI...
# 24  I just upgraded from an iphone8 to the iphone ...
# 25  Yesterday my brother brought I phone xr for hi...
# 26  I used this device only 5 days because I borro...
# 27  Bought it 5 days before . I love this phone wi...
# 28  This I phone promises a premium design, look, ...
# 29  This iPhone is probably the best iPhone that A...
# ..                                                ...
# 70  My both sister have iPhone and whenever I see ...
# 71  Best product.Apple iPhoneI like product.I thin...
# 72  It is not good for money because we get more m...
# 73  Apple we also know the apple a huge mobile , w...
# 74  Everyone knows that its very costly but to be ...
# 75  I phones is giid phones but costly so Better t...
# 76  It has been a month since I started using my i...
# 77  Whole feathure are amazing.Eas4th to use. Desi...
# 78  Woooh I never seen this iphone xr I have iphon...
# 79  Very nice phone. I love this. I am going to bu...
# 80  I think this phone is just meant for showoff a...
# 81  The worst phone a person could ever have in hi...
# 82  Guys .,My friend have I phone xr ,And I have r...
# 83  I HAVE NEVER BEEN AN IPHONE USER UNTIL LAST TI...
# 84  I just upgraded from an iphone8 to the iphone ...
# 85  Yesterday my brother brought I phone xr for hi...
# 86  I used this device only 5 days because I borro...
# 87  Bought it 5 days before . I love this phone wi...
# 88  This I phone promises a premium design, look, ...
# 89  This iPhone is probably the best iPhone that A...
# 90  My both sister have iPhone and whenever I see ...
# 91  Best product.Apple iPhoneI like product.I thin...
# 92  It is not good for money because we get more m...
# 93  Apple we also know the apple a huge mobile , w...
# 94  Everyone knows that its very costly but to be ...
# 95  I phones is giid phones but costly so Better t...
# 96  It has been a month since I started using my i...
# 97  Whole feathure are amazing.Eas4th to use. Desi...
# 98  Woooh I never seen this iphone xr I have iphon...
# 99  Very nice phone. I love this. I am going to bu...
#
# [100 rows x 3 columns]

# %%
df.to_excel('/Users/Arjun D H/Documents/review_apple_xr.xlsx',header=True)
