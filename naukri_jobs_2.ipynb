# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url ="https://www.naukri.com/jobs-in-united-states-us?qsb_section=ni"+str(index)+"0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='row  ']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 250

# %%
print(all_section[0])
# Out:
# Senior Devops Engineer (ci/cd Bamboo)
# Cambridge Technology Enterprises Limited
# 3.7(30 reviews)
# 4-9 yrs
# Mumbai, Bengaluru, Hyderabad, United States (U.S)
# Maven, GIT, Continuous Integration, Ant, SVN, Gradle, Bamboo
# Key Roles,Responsibilities: Should have the below: Experience in working with CI tools like Bamboo for automated build and Deployment Need ...
# Not disclosed
# Posted by HR , 7 days ago

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,250),columns=['job_Role','company','reviews','experience','location','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #job_role
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #company
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #reviews
    except IndexError:
        df.iloc[idx,2]=np.nan
    try:
        df.iloc[idx,3]=scn[3] #experience
    except IndexError:
        df.iloc[idx,3]=np.nan
    try:
        df.iloc[idx,4]=scn[4] #location
    except IndexError:
        df.iloc[idx,4]=np.nan
    try:
        df.iloc[idx,5]=scn[5] #description
    except IndexError:
        df.iloc[idx,5]=np.nan

# %%
df
# Out:
#                                               job_Role  \
# 0                Senior Devops Engineer (ci/cd Bamboo)
# 1    Sales Officer/sales Reps- Agra, US Nagar & Mor...
# 2    Housekeeping and Restaurant Manager Food and B...
# 3    Front Office-hyatt Regency-denver -usa--12 Mon...
# 4     Sales Executive, R&D and Quality Control Manager
# 5                                IT Support Freelancer
# 6             Oracle DBA ( Postgresql / Mongodb) - USA
# 7                       Chemical / Production Engineer
# 8                                    Senior Officer HR
# 9                             Product Designer (ui/ux)
# 10   Retail Sales JOB For a Jewellery Store in Duba...
# 11   Credit Control Manager / Accounts Receivable M...
# 12                           Assistant Finance Manager
# 13                                         Optometrist
# 14                                Hydraulic Technician
# 15                          Head Supply Chain (retail)
# ...

# %%
df.to_csv('/Users/Arjun D H/Documents/naukri2_job.csv',header=True)
