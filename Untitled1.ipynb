# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url = "https://www.indeed.com/cmp/Upwork/reviews?fcountry=ALL&fjobtitle=Freelancer"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='cmp-review-container']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 60

# %%
print(all_section[8])
# Out:
# 5.0
# Great Website
# Freelancer (Current Employee) –  Leicester, Leicestershire – May 21, 2019
# This is a great website to develop skills and build your resume. It helps give you idea regarding work culture and how to develop clients relation and work remotely!
# Pros
# Work from anywhere
# Cons
# Difficult to find client at first
# Was this review helpful?
# Yes
# No 2
# Report
# Share

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,60),columns=['review','experience','position','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #review
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #experience
    except IndexError:
        df.iloc[idx,1]=np.nan
    try:
        df.iloc[idx,2]=scn[2] #position
    except IndexError:
        df.iloc[idx,2]=np.nan
    try:
        df.iloc[idx,3]=scn[3] #description
    except IndexError:
        df.iloc[idx,3]=np.nan

# %%
df
# Out:
#    review                                         experience  \
# 0     5.0               Good for Beginners/part time workers
# 1     2.0                 Exploited by this company for 3yrs
# 2     5.0                              Amazing place to work
# 3     2.0                                Interesting concept
# 4     4.0  Upwork is great for Freelancers but very compe...
# 5     1.0   Terrible company, refuse to delete personal data
# 6     4.0                                          Free time
# 7     1.0                                Disgraceful company
# 8     5.0                                      Great Website
# 9     5.0                                    As a freelancer
# 10    5.0   It's tough, but once you're in you can make bank
# 11    5.0         One of The Best Website for Freelance Work
# 12    5.0               Good for Beginners/part time workers
# 13    2.0                 Exploited by this company for 3yrs
# ...
