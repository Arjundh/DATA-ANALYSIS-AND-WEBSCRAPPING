# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support.expected_conditions import  visibility_of_element_located
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import re
import pandas as pd
import numpy as np
import time

# %%
#launch url
all_section=[]
driver = webdriver.Firefox(executable_path='C://Users//Arjun D H//geckodriver-v0.24.0-win64//geckodriver.exe')
for index in range(0,5):
    print(index)
    url ="https://www.deccanchronicle.com/technology"+str(index)+"0"
    driver.get(url)
    driver.implicitly_wait(50)
    section = driver.find_elements_by_xpath("//*[@class='col-sm-12 col-xs-12 tstry-feed-sml-a']")
    for i in section:
        all_section.append(i.text)
driver.close()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
print(len(all_section))
# Out:
# 0

# %%
print(all_section[2])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-bf32caa4288b> in <module>
# ----> 1 print(all_section[2])
#
# IndexError: list index out of range

# %%
import pandas as pd
df=pd.DataFrame(index=range(0,40),columns=['head_line','description'])
for idx,section in enumerate(all_section):
    scn=section.split('\n')
    try:
        df.iloc[idx,0]=scn[0] #head_line
    except IndexError:
        df.iloc[idx,0]=np.nan
    try:
        df.iloc[idx,1]=scn[1] #description
    except IndexError:
        df.iloc[idx,1]=np.nan

# %%
df
# Out:
#                                             head_line description
# 0   'Fought for long, but today I gave up': CCD fo...         NaN
# 1              CCD founder VG Siddhartha goes missing         NaN
# 2      Gavaskar questions Kohli's position as captain         NaN
# 3         Live: Triple Talaq Bill set to face RS test         NaN
# 4       Unnao rape survivor accident: FIR against MLA         NaN
# 5                                                             NaN
# 6                                                             NaN
# 7                                                             NaN
# 8   'Fought for long, but today I gave up': CCD fo...         NaN
# 9              CCD founder VG Siddhartha goes missing         NaN
# 10     Gavaskar questions Kohli's position as captain         NaN
# 11        Live: Triple Talaq Bill set to face RS test         NaN
# 12      Unnao rape survivor accident: FIR against MLA         NaN
# 13                                                            NaN
# 14                                                            NaN
# 15                                                            NaN
# 16  'Fought for long, but today I gave up': CCD fo...         NaN
# 17             CCD founder VG Siddhartha goes missing         NaN
# 18     Gavaskar questions Kohli's position as captain         NaN
# 19        Live: Triple Talaq Bill set to face RS test         NaN
# 20      Unnao rape survivor accident: FIR against MLA         NaN
# 21                                                            NaN
# 22                                                            NaN
# 23                                                            NaN
# 24  'Fought for long, but today I gave up': CCD fo...         NaN
# 25             CCD founder VG Siddhartha goes missing         NaN
# 26     Gavaskar questions Kohli's position as captain         NaN
# 27        Live: Triple Talaq Bill set to face RS test         NaN
# 28      Unnao rape survivor accident: FIR against MLA         NaN
# 29                                                            NaN
# 30                                                            NaN
# 31                                                            NaN
# 32  'Fought for long, but today I gave up': CCD fo...         NaN
# 33             CCD founder VG Siddhartha goes missing         NaN
# 34     Gavaskar questions Kohli's position as captain         NaN
# 35        Live: Triple Talaq Bill set to face RS test         NaN
# 36      Unnao rape survivor accident: FIR against MLA         NaN
# 37                                                            NaN
# 38                                                            NaN
# 39                                                            NaN
